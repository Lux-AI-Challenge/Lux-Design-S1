# %%
# to get the data, run mapanalysis.ts first with ts-node mapanalysis.ts
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
resources = ['wood', 'coal', 'uranium']

# %%
df = pd.read_json("mapgendist.json")

# %%
rows = []
for k in df.keys():
    for r in df[k]['resources']:
        rows.append((r['wood'], r['coal'], r['uranium'], r['woodTiles'], r['coalTiles'], r['uraniumTiles'], k))

# %%
data = pd.DataFrame(np.array(rows), columns=
                    ['wood', 'coal', 'uranium', 'woodTiles', 'coalTiles', 'uraniumTiles', 'size']
                   )

# %%
fig = plt.figure(figsize=(15,10))
ax = None
for j, size in enumerate([12,16,24,32]):

    for i, r in enumerate(resources):
        k = (i+1 + j*len(resources))
        ax = plt.subplot(4, 3, k, sharex=ax, sharey=ax)
        plt.hist(data[data['size'] == size][r], bins=15)
        plt.title(f"Histogram of amount of {r} in a {size}x{size} map")
plt.tight_layout()

# %%
data.groupby('size').describe()['woodTiles']
# Out:
#        count       mean        std   min   25%   50%   75%   max
# size
# 12    2555.0  18.367123   2.710492  12.0  16.0  18.0  20.0  38.0
# 16    2369.0  21.317011   4.069649  14.0  18.0  20.0  24.0  40.0
# 24    2580.0  32.168992   7.251701  16.0  27.5  32.0  36.0  62.0
# 32    2496.0  50.604167  10.369698  18.0  44.0  50.0  58.0  94.0

# %%
data.groupby('size').describe()['wood']
# Out:
#        count          mean          std     min      25%      50%      75%  \
# size
# 12    2555.0   7319.429354   603.334032  3656.0   6968.0   7204.0   7592.0
# 16    2369.0   7871.590545   835.118674  4536.0   7224.0   7696.0   8354.0
# 24    2580.0  10020.524031  1488.633584  6670.0   8946.0   9936.0  10956.0
# 32    2496.0  13696.815705  2135.826913  7324.0  12237.5  13618.0  15026.5
#
#           max
# size
# 12    11270.0
# 16    11612.0
# 24    16242.0
# 32    22258.0

# %%
data.groupby('size').describe()['coal']
# Out:
#        count         mean          std     min     25%     50%     75%  \
# size
# 12    2555.0  2179.419178   849.780458  1500.0  1560.0  1654.0  2390.0
# 16    2369.0  2850.275222  1308.933261  1500.0  1620.0  2384.0  3716.0
# 24    2580.0  4496.091473  2141.641370  1500.0  3010.0  3963.0  5610.5
# 32    2496.0  6849.902244  3013.252488  1510.0  4616.0  6704.0  8548.5
#
#           max
# size
# 12    10038.0
# 16    10624.0
# 24    15110.0
# 32    19538.0

# %%
data.groupby('size').describe()['uranium']
# Out:
#        count         mean          std    min     25%     50%     75%      max
# size
# 12    2555.0   944.368689   632.602538  500.0   542.0   584.0  1120.0   6760.0
# 16    2369.0  1732.107218  1136.866835  500.0  1018.0  1590.0  2338.0   8492.0
# 24    2580.0  3662.350388  1949.839370  500.0  2186.0  3414.0  4970.0  12590.0
# 32    2496.0  6574.111378  2865.684138  528.0  4435.5  6419.0  8502.5  22050.0

# %%
data.groupby('size').describe()['uraniumTiles']
# Out:
#        count       mean       std  min   25%   50%   75%   max
# size
# 12    2555.0   3.312720  2.011823  2.0   2.0   2.0   4.0  20.0
# 16    2369.0   6.024483  3.725516  2.0   4.0   6.0   8.0  26.0
# 24    2580.0  12.641085  6.433712  2.0   8.0  12.0  16.0  40.0
# 32    2496.0  22.606571  9.498817  2.0  16.0  22.0  30.0  72.0
